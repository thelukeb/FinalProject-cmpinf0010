# %%
import pandas as pd
import numpy as np

traffic_data = pd.read_csv("trafficpittsburgh.csv", 
                                       index_col="id") # use the column named _id as the row index

# %%
traffic_data.head(10)
# Out:
#             device_id    record_oid count_start_date count_end_date  \
# id
# 1011743669         85  1.445865e+09       2019-04-18     2019-04-26
# 1026101993        140  1.121444e+09       2019-01-24            NaN
# 1032382575         11  1.539893e+09       2018-08-28     2018-09-04
# 103627606           9  7.341951e+08       2018-07-17     2018-08-01
# 1039546167        144           NaN              NaN            NaN
# 1041392556         76  5.713472e+08       2019-03-22     2019-03-29
# 1047444948         17  1.366891e+09       2018-10-18            NaN
# 1053645660         87  8.042089e+08       2019-04-18     2019-04-26
# 1073440033        156  1.736165e+09       2017-07-28            NaN
# 1092885547        143           NaN              NaN            NaN
#
#             average_daily_car_traffic  average_daily_bike_traffic  \
# id
# 1011743669                     4949.0                         NaN
# 1026101993                        NaN                         NaN
# ...
